# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghan539/Gen_AI-Workshop/blob/main/Gen_AI_p4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# -------------------------------------------------
# 1. Training text
# -------------------------------------------------

text = "hello world hello world hello world"

# Convert text to lowercase
text = text.lower()

# -------------------------------------------------
# 2. Create character vocabulary
# -------------------------------------------------

chars = sorted(list(set(text)))

char_to_int = {c: i for i, c in enumerate(chars)}
int_to_char = {i: c for i, c in enumerate(chars)}

vocab_size = len(chars)

print("Characters:", chars)
print("Vocabulary size:", vocab_size)

# -------------------------------------------------
# 3. Create input sequences and target characters
# -------------------------------------------------

seq_length = 5

X = []
y = []

for i in range(len(text) - seq_length):
    sequence = text[i:i + seq_length]
    target = text[i + seq_length]

    X.append([char_to_int[c] for c in sequence])
    y.append(char_to_int[target])

X = np.array(X)
y = np.array(y)

# -------------------------------------------------
# 4. Reshape input
# -------------------------------------------------

X = X.reshape(X.shape[0], X.shape[1], 1)

# Normalize input
X = X / float(vocab_size)

# -------------------------------------------------
# 5. Build LSTM model
# -------------------------------------------------

model = Sequential()

model.add(
    LSTM(
        64,
        input_shape=(seq_length, 1)
    )
)

model.add(
    Dense(vocab_size, activation="softmax")
)

# -------------------------------------------------
# 6. Compile model
# -------------------------------------------------

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# -------------------------------------------------
# 7. Display model
# -------------------------------------------------

model.summary()

# -------------------------------------------------
# 8. Train model
# -------------------------------------------------

model.fit(
    X,
    y,
    epochs=100,
    batch_size=8,
    verbose=1
)

# -------------------------------------------------
# 9. Predict next character
# -------------------------------------------------

seed = "hello"

encoded_seed = np.array(
    [[char_to_int[c] for c in seed]]
)

encoded_seed = encoded_seed.reshape(1, seq_length, 1)
encoded_seed = encoded_seed / float(vocab_size)

prediction = model.predict(encoded_seed, verbose=0)

predicted_index = np.argmax(prediction[0])

predicted_char = int_to_char[predicted_index]

print("\nSeed text:", seed)
print("Predicted next character:", predicted_char)
# Out:
# Characters: [' ', 'd', 'e', 'h', 'l', 'o', 'r', 'w']
# Vocabulary size: 8
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,416 (68.03 KB)
#  Trainable params: 17,416 (68.03 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.1000 - loss: 2.0819
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1000 - loss: 2.0726
# Epoch 3/100
# ...
